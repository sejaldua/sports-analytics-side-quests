# %% [markdown]
# ### Scrape Schedule

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# Scrape the NFL schedule for the current season
url = "https://www.pro-football-reference.com/years/2025/games.htm"
response = requests.get(url)
response.raise_for_status()

soup = BeautifulSoup(response.text, "html.parser")

# Find the schedule table
table = soup.find("table", id="games")

# Extract headers
headers = [th.get_text(strip=True) for th in table.find("thead").find_all("th")]

# Extract rows
rows = []
for row in table.find("tbody").find_all("tr"):
    if "class" in row.attrs and "thead" in row["class"]:
        continue  # skip mid-table headers
    cells = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])]
    rows.append(cells)

# Create DataFrame
sked_df = pd.DataFrame(rows, columns=headers)
sked_df.columns = ['Week', 'Day', 'Date', 'Time', 'Visitor', 'H/A', 'Home', 'Boxscore', 'PtsW', 'PtsL', 'YdsW', 'TOW', 'YdsL', 'TOL']
sked_df = sked_df[['Week', 'Day', 'Date', 'Time', 'Visitor', 'H/A', 'Home']]
sked_df['Matchup String'] = sked_df['Visitor'] + " " + sked_df['H/A'].apply(lambda x: "vs" if x == "" else "@") + " " + sked_df['Home']
sked_df['Start Time'] = sked_df['Day'] + ' ' + sked_df['Time']
# roll up the start time column into buckets: Thursday, Sunday Morning, Sunday Early Afternoon, Sunday Late Afternoon, Sunday Night, Monday Night... I don't care about Friday or Saturday
def bucket_start_time(start_time):
    if "Thu" in start_time:
        return "Thursday"
    elif "Mon" in start_time:
        return "Monday Night"
    elif "Sun" in start_time:
        time_part = start_time.split(' ')[-1]
        hour = int(time_part.split(':')[0])
        if hour < 12 and time_part.endswith('AM'):
            return "Sunday Morning"
        elif 1 <= hour < 4 and time_part.endswith('PM'):
            return "Sunday Early Afternoon"
        elif 4 <= hour < 8 and time_part.endswith('PM'):
            return "Sunday Late Afternoon"
        else:
            return "Sunday Night"
    else:
        return "Other"
sked_df['Week'] = sked_df['Week'].astype(int)
sked_df['Start Time Bucket'] = sked_df['Start Time'].apply(bucket_start_time)
sked_df
# Out:
#      Week  Day        Date    Time                Visitor H/A  \
# 0       1  Thu  2025-09-04  8:20PM    Philadelphia Eagles
# 1       1  Fri  2025-09-05  8:00PM   Los Angeles Chargers
# 2       1  Sun  2025-09-07  1:00PM    Pittsburgh Steelers   @
# 3       1  Sun  2025-09-07  1:00PM  Washington Commanders
# 4       1  Sun  2025-09-07  1:00PM      Las Vegas Raiders   @
# ..    ...  ...         ...     ...                    ...  ..
# 267    18  Sun  2026-01-04  1:00PM       Tennessee Titans   @
# 268    18  Sun  2026-01-04  1:00PM       Baltimore Ravens   @
# 269    18  Sun  2026-01-04  1:00PM   Los Angeles Chargers   @
# 270    18  Sun  2026-01-04  1:00PM       Seattle Seahawks   @
# 271    18  Sun  2026-01-04  1:00PM  Washington Commanders   @
#
#                      Home                               Matchup String  \
# 0          Dallas Cowboys        Philadelphia Eagles vs Dallas Cowboys
# 1      Kansas City Chiefs   Los Angeles Chargers vs Kansas City Chiefs
# 2           New York Jets          Pittsburgh Steelers @ New York Jets
# 3         New York Giants     Washington Commanders vs New York Giants
# 4    New England Patriots     Las Vegas Raiders @ New England Patriots
# ..                    ...                                          ...
# 267  Jacksonville Jaguars      Tennessee Titans @ Jacksonville Jaguars
# 268   Pittsburgh Steelers       Baltimore Ravens @ Pittsburgh Steelers
# 269        Denver Broncos        Los Angeles Chargers @ Denver Broncos
# 270   San Francisco 49ers       Seattle Seahawks @ San Francisco 49ers
# 271   Philadelphia Eagles  Washington Commanders @ Philadelphia Eagles
#
#      Start Time       Start Time Bucket
# 0    Thu 8:20PM                Thursday
# 1    Fri 8:00PM                   Other
# 2    Sun 1:00PM  Sunday Early Afternoon
# 3    Sun 1:00PM  Sunday Early Afternoon
# 4    Sun 1:00PM  Sunday Early Afternoon
# ..          ...                     ...
# 267  Sun 1:00PM  Sunday Early Afternoon
# 268  Sun 1:00PM  Sunday Early Afternoon
# 269  Sun 1:00PM  Sunday Early Afternoon
# 270  Sun 1:00PM  Sunday Early Afternoon
# 271  Sun 1:00PM  Sunday Early Afternoon
#
# [272 rows x 10 columns]

# %%
pivoted = pd.pivot_table(sked_df, index='Start Time Bucket', columns='Week', values='Matchup String', aggfunc='count').fillna(0).astype(int)
pivoted = pivoted.reindex(index=["Thursday", "Sunday Morning", "Sunday Early Afternoon", "Sunday Late Afternoon", "Sunday Night", "Monday Night", "Other"])
pivoted.index.name = None
pivoted.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_76885_row0_col0, #T_76885_row0_col1, #T_76885_row0_col2, #T_76885_row0_col3, #T_76885_row0_col4, #T_76885_row0_col5, #T_76885_row0_col6, #T_76885_row0_col7, #T_76885_row0_col8, #T_76885_row0_col9, #T_76885_row0_col10, #T_76885_row0_col11, #T_76885_row0_col13, #T_76885_row0_col14, #T_76885_row0_col15 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_76885_row0_col12, #T_76885_row0_col16, #T_76885_row1_col3, #T_76885_row1_col4, #T_76885_row1_col5, #T_76885_row1_col6, #T_76885_row1_col9, #T_76885_row1_col10, #T_76885_row2_col17, #T_76885_row3_col14, #T_76885_row4_col0, #T_76885_row4_col1, #T_76885_row4_col2, #T_76885_row4_col3, #T_76885_row4_col4, #T_76885_row4_col5, #T_76885_row4_col6, #T_76885_row4_col7, #T_76885_row4_col8, #T_76885_row4_col9, #T_76885_row4_col10, #T_76885_row4_col11, #T_76885_row4_col12, #T_76885_row4_col13, #T_76885_row4_col14, #T_76885_row4_col15, #T_76885_row4_col16, #T_76885_row5_col1, #T_76885_row5_col3, #T_76885_row5_col5, #T_76885_row5_col6, #T_76885_row6_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_76885_row0_col17, #T_76885_row1_col0, #T_76885_row1_col1, #T_76885_row1_col2, #T_76885_row1_col7, #T_76885_row1_col8, #T_76885_row1_col11, #T_76885_row1_col12, #T_76885_row1_col13, #T_76885_row1_col14, #T_76885_row1_col15, #T_76885_row1_col16, #T_76885_row1_col17, #T_76885_row2_col4, #T_76885_row2_col6, #T_76885_row3_col17, #T_76885_row4_col17, #T_76885_row5_col17, #T_76885_row6_col1, #T_76885_row6_col2, #T_76885_row6_col3, #T_76885_row6_col4, #T_76885_row6_col5, #T_76885_row6_col6, #T_76885_row6_col7, #T_76885_row6_col8, #T_76885_row6_col9, #T_76885_row6_col10, #T_76885_row6_col11, #T_76885_row6_col13, #T_76885_row6_col14, #T_76885_row6_col16, #T_76885_row6_col17 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T
# | Week 10 | ATL @ IND | Berlin, Germany |
# | Week 11 | WAS @ MIA | Madrid, Spain |

# %%
sked_df[sked_df['Start Time Bucket'] == 'Other']
# Out:
#      Week  Day        Date    Time               Visitor H/A  \
# 1       1  Fri  2025-09-05  8:00PM  Los Angeles Chargers
# 181    13  Fri  2025-11-28  3:00PM         Chicago Bears   @
# 225    16  Sat  2025-12-20  1:00PM     Green Bay Packers   @
# 226    16  Sat  2025-12-20  1:00PM   Philadelphia Eagles   @
#
#                       Home                               Matchup String  \
# 1       Kansas City Chiefs   Los Angeles Chargers vs Kansas City Chiefs
# 181    Philadelphia Eagles          Chicago Bears @ Philadelphia Eagles
# 225          Chicago Bears            Green Bay Packers @ Chicago Bears
# 226  Washington Commanders  Philadelphia Eagles @ Washington Commanders
#
#      Start Time Start Time Bucket
# 1    Fri 8:00PM             Other
# 181  Fri 3:00PM             Other
# 225  Sat 1:00PM             Other
# 226  Sat 1:00PM             Other

# %% [markdown]
# Among the games labeled "Other," we have Friday games and Saturday games. The first Friday game shown in the dataframe above is the Dublin game mentioned earlier. The other Friday game is a Black Friday game during the afternoon (*Shameless plug: the final night of NBA Cup Group Play is at night on Black Friday*).
#
# The two Saturday games? I honestly have no idea why the NFL is doing those. I guess I'll find out soon enough.

# %% [markdown]
# My real reason for investigating these weekly schedule start time quirks is because I wanted to understand why the f--- the NFL is scheduling 9 games in the 1pm window. I can barely handle Scott Hanson's Octobox as it is... the Brady Bunch view is just too much for me, so there's gotta be good reason.

# %%
sked_df[sked_df['Week'] == 2]
# Out:
#     Week  Day        Date     Time               Visitor H/A  \
# 16     2  Thu  2025-09-11   8:15PM     Green Bay Packers
# 17     2  Sun  2025-09-14   1:00PM  New England Patriots   @
# 18     2  Sun  2025-09-14   1:00PM        Dallas Cowboys
# 19     2  Sun  2025-09-14   1:00PM         Detroit Lions
# 20     2  Sun  2025-09-14   1:00PM         Buffalo Bills   @
# 21     2  Sun  2025-09-14   1:00PM   San Francisco 49ers   @
# 22     2  Sun  2025-09-14   1:00PM      Baltimore Ravens
# 23     2  Sun  2025-09-14   1:00PM      Los Angeles Rams   @
# 24     2  Sun  2025-09-14   1:00PM    Cincinnati Bengals
# 25     2  Sun  2025-09-14   1:00PM      Seattle Seahawks   @
# 26     2  Sun  2025-09-14   4:05PM    Indianapolis Colts
# 27     2  Sun  2025-09-14   4:05PM     Arizona Cardinals
# 28     2  Sun  2025-09-14   4:25PM   Philadelphia Eagles   @
# 29     2  Sun  2025-09-14   8:20PM       Atlanta Falcons   @
# 30     2  Mon  2025-09-15   7:00PM  Tampa Bay Buccaneers   @
# 31     2  Mon  2025-09-15  10:00PM  Los Angeles Chargers   @
#
#                      Home                              Matchup String  \
# 16  Washington Commanders  Green Bay Packers vs Washington Commanders
# 17         Miami Dolphins       New England Patriots @ Miami Dolphins
# 18        New York Giants           Dallas Cowboys vs New York Giants
# 19          Chicago Bears              Detroit Lions vs Chicago Bears
# 20          New York Jets               Buffalo Bills @ New York Jets
